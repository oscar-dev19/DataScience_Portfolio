# %% [markdown]
# # EDA of my Zillow Median Rent Predictor.
# ---

# %%
import os

# %% [markdown]
# ## Zillow Data Directory
# ---

# %%
ZILLOW_DATA_ROOT_DIR = './zillow_data/'
CITY_MEDIAN_RENTAL_DATAFILE = 'City_MedianRentalPrice_AllHomes.csv'
FULL_MEDIAN_RENTAL_DATA_PATH = f'{ZILLOW_DATA_ROOT_DIR}{CITY_MEDIAN_RENTAL_DATAFILE}'

# %%
FULL_MEDIAN_RENTAL_DATA_PATH
# Out:
# './zillow_data/City_MedianRentalPrice_AllHomes.csv'

# %% [markdown]
# ## Loading Data into Dataframe
# ---

# %%
import pandas as pd

MedianRentalPrice_Dataframe = pd.read_csv(FULL_MEDIAN_RENTAL_DATA_PATH)

# %%
MedianRentalPrice_Dataframe
# Out:
#       Unnamed: 0       RegionName State  \
# 0              0         New York    NY
# 1              1      Los Angeles    CA
# 2              2          Houston    TX
# 3              3          Chicago    IL
# 4              4      San Antonio    TX
# ...          ...              ...   ...
# 1694        1694  Hillsboro Beach    FL
# 1695        1695       Amagansett    NY
# 1696        1696           Quogue    NY
# 1697        1697            Ogden    KS
# 1698        1698        Wainscott    NY
#
#                                       Metro          CountyName  SizeRank  \
# 0               New York-Newark-Jersey City       Queens County         1
# 1            Los Angeles-Long Beach-Anaheim  Los Angeles County         2
# 2          Houston-The Woodlands-Sugar Land       Harris County         3
# 3                  Chicago-Naperville-Elgin         Cook County         4
# 4                 San Antonio-New Braunfels        Bexar County         5
# ...                                     ...                 ...       ...
# 1694  Miami-Fort Lauderdale-West Palm Beach      Broward County      1695
# 1695            New York-Newark-Jersey City      Suffolk County      1696
# 1696            New York-Newark-Jersey City      Suffolk County      1697
# 1697                              Manhattan        Riley County      1698
# 1698            New York-Newark-Jersey City      Suffolk County      1699
#
#       2010-01  2010-02  2010-03  2010-04  ...  2019-03  2019-04  2019-05  \
# 0         NaN      NaN      NaN      NaN  ...   2800.0   2875.0   2900.0
# 1         NaN      NaN      NaN      NaN  ...   3500.0   3500.0   3500.0
# 2         NaN      NaN      NaN      NaN  ...   1500.0   1544.0   1550.0
# 3         NaN   1600.0   1500.0   1500.0  ...   1775.0   1795.0   1800.0
# 4         NaN      NaN      NaN      NaN  ...   1300.0   1300.0   1325.0
# ...       ...      ...      ...      ...  ...      ...      ...      ...
# 1694      NaN      NaN      NaN      NaN  ...   2700.0   2650.0   2737.5
# 1695      NaN      NaN      NaN      NaN  ...  30000.0  33333.0  36000.0
# 1696      NaN      NaN      NaN      NaN  ...  30000.0  30000.0  30000.0
# 1697      NaN      NaN      NaN      NaN  ...    990.0    990.0    990.0
# 1698      NaN      NaN      NaN      NaN  ...  40000.0  34750.0  35000.0
#
#       2019-06  2019-07  2019-08  2019-09  2019-10  2019-11  2019-12
# 0      2895.0   2850.0   2925.0   2900.0   2900.0   2899.0   2900.0
# 1      3520.0   3500.0   3600.0   3607.0   3665.0   3600.0   3550.0
# 2      1550.0   1550.0   1550.0   1550.0   1500.0   1500.0   1500.0
# 3      1800.0   1800.0   1812.5   1800.0   1800.0   1766.0   1750.0
# 4      1345.0   1349.0   1322.5   1299.0   1300.0   1299.0   1300.0
# ...       ...      ...      ...      ...      ...      ...      ...
# 1694   2775.0   3000.0   3000.0   3150.0   3000.0   3150.0   3395.0
# 1695  36333.0  35000.0  30000.0  30000.0  34000.0  33041.5  35000.0
# 1696  30000.0  30000.0  29500.0  30000.0  30000.0  30000.0  31666.0
# 1697    990.0    909.0    939.0    909.0    909.0    939.0    909.0
# 1698  35000.0  35000.0  30000.0  30000.0  28333.0  25000.0  28333.0
#
# [1699 rows x 126 columns]

# %%
MedianRentalPrice_Dataframe.columns
# Out:
# Index(['Unnamed: 0', 'RegionName', 'State', 'Metro', 'CountyName', 'SizeRank',
#        '2010-01', '2010-02', '2010-03', '2010-04',
#        ...
#        '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08',
#        '2019-09', '2019-10', '2019-11', '2019-12'],
#       dtype='object', length=126)

# %%
MedianRentalPrice_Dataframe = MedianRentalPrice_Dataframe.drop(['Unnamed: 0'], axis=1)

# %%
MedianRentalPrice_Dataframe
# Out:
#            RegionName State                                  Metro  \
# 0            New York    NY            New York-Newark-Jersey City
# 1         Los Angeles    CA         Los Angeles-Long Beach-Anaheim
# 2             Houston    TX       Houston-The Woodlands-Sugar Land
# 3             Chicago    IL               Chicago-Naperville-Elgin
# 4         San Antonio    TX              San Antonio-New Braunfels
# ...               ...   ...                                    ...
# 1694  Hillsboro Beach    FL  Miami-Fort Lauderdale-West Palm Beach
# 1695       Amagansett    NY            New York-Newark-Jersey City
# 1696           Quogue    NY            New York-Newark-Jersey City
# 1697            Ogden    KS                              Manhattan
# 1698        Wainscott    NY            New York-Newark-Jersey City
#
#               CountyName  SizeRank  2010-01  2010-02  2010-03  2010-04  \
# 0          Queens County         1      NaN      NaN      NaN      NaN
# 1     Los Angeles County         2      NaN      NaN      NaN      NaN
# 2          Harris County         3      NaN      NaN      NaN      NaN
# 3            Cook County         4      NaN   1600.0   1500.0   1500.0
# 4           Bexar County         5      NaN      NaN      NaN      NaN
# ...                  ...       ...      ...      ...      ...      ...
# 1694      Broward County      1695      NaN      NaN      NaN      NaN
# 1695      Suffolk County      1696      NaN      NaN      NaN      NaN
# 1696      Suffolk County      1697      NaN      NaN      NaN      NaN
# 1697        Riley County      1698      NaN      NaN      NaN      NaN
# 1698      Suffolk County      1699      NaN      NaN      NaN      NaN
#
#       2010-05  ...  2019-03  2019-04  2019-05  2019-06  2019-07  2019-08  \
# 0      2300.0  ...   2800.0   2875.0   2900.0   2895.0   2850.0   2925.0
# 1         NaN  ...   3500.0   3500.0   3500.0   3520.0   3500.0   3600.0
# 2         NaN  ...   1500.0   1544.0   1550.0   1550.0   1550.0   1550.0
# 3      1500.0  ...   1775.0   1795.0   1800.0   1800.0   1800.0   1812.5
# 4         NaN  ...   1300.0   1300.0   1325.0   1345.0   1349.0   1322.5
# ...       ...  ...      ...      ...      ...      ...      ...      ...
# 1694      NaN  ...   2700.0   2650.0   2737.5   2775.0   3000.0   3000.0
# 1695      NaN  ...  30000.0  33333.0  36000.0  36333.0  35000.0  30000.0
# 1696      NaN  ...  30000.0  30000.0  30000.0  30000.0  30000.0  29500.0
# 1697      NaN  ...    990.0    990.0    990.0    990.0    909.0    939.0
# 1698      NaN  ...  40000.0  34750.0  35000.0  35000.0  35000.0  30000.0
#
#       2019-09  2019-10  2019-11  2019-12
# 0      2900.0   2900.0   2899.0   2900.0
# 1      3607.0   3665.0   3600.0   3550.0
# 2      1550.0   1500.0   1500.0   1500.0
# 3      1800.0   1800.0   1766.0   1750.0
# 4      1299.0   1300.0   1299.0   1300.0
# ...       ...      ...      ...      ...
# 1694   3150.0   3000.0   3150.0   3395.0
# 1695  30000.0  34000.0  33041.5  35000.0
# 1696  30000.0  30000.0  30000.0  31666.0
# 1697    909.0    909.0    939.0    909.0
# 1698  30000.0  28333.0  25000.0  28333.0
#
# [1699 rows x 125 columns]

# %%
MedianRentalPrice_Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699 entries, 0 to 1698
# Columns: 125 entries, RegionName to 2019-12
# dtypes: float64(120), int64(1), object(4)
# memory usage: 1.6+ MB

# %%
MedianRentalPrice_Dataframe.describe()
# Out:
#           SizeRank  2010-01      2010-02      2010-03      2010-04  \
# count  1699.000000      1.0    30.000000    62.000000    80.000000
# mean    849.992348    895.0  1408.433333  1343.040323  1408.325000
# std     490.601169      NaN   444.181264   395.872934   473.968741
# min       1.000000    895.0   795.000000   737.500000   737.500000
# 25%     425.000000    895.0  1112.500000  1058.750000  1050.000000
# 50%     850.000000    895.0  1300.000000  1250.000000  1295.000000
# 75%    1274.500000    895.0  1600.000000  1500.000000  1671.875000
# max    1699.000000    895.0  2400.000000  2500.000000  3300.000000
#
#            2010-05      2010-06      2010-07      2010-08      2010-09  ...  \
# count    83.000000    84.000000    90.000000    99.000000   120.000000  ...
# mean   1420.361446  1446.375000  1481.850000  1547.792929  1531.279167  ...
# std     479.819442   507.469388   547.253574   663.246884   599.763041  ...
# min     750.000000   795.000000   775.000000   825.000000   795.000000  ...
# 25%    1061.250000  1076.875000  1095.000000  1100.000000  1100.000000  ...
# 50%    1295.000000  1295.000000  1297.500000  1300.000000  1350.000000  ...
# 75%    1660.000000  1687.500000  1837.500000  1800.000000  1900.000000  ...
# max    3225.000000  3200.000000  3325.000000  4200.000000  3800.000000  ...
#
#             2019-03       2019-04       2019-05       2019-06       2019-07  \
# count   1699.000000   1699.000000   1699.000000   1699.000000   1699.000000
# mean    1922.993231   1940.743967   1958.058564   1961.466157   1959.818128
# std     2039.147687   2050.303717   2137.045249   2119.174137   2040.416334
# min      550.000000    575.000000    575.000000    600.000000    600.000000
# 25%     1300.000000   1300.000000   1325.000000   1325.000000   1318.750000
# 50%     1620.000000   1650.000000   1650.000000   1650.000000   1662.500000
# 75%     2100.000000   2100.000000   2125.000000   2150.000000   2175.000000
# max    45000.000000  47500.000000  50000.000000  50000.000000  45000.000000
#
#             2019-08       2019-09       2019-10       2019-11       2019-12
# count   1699.000000   1699.000000   1699.000000   1699.000000   1699.000000
# mean    1948.314891   1937.666569   1933.940259   1923.351383   1929.953208
# std     1895.394018   1839.838980   1931.682722   1811.601190   1884.996587
# min      590.000000    565.000000    575.000000    575.000000    525.000000
# 25%     1325.000000   1300.000000   1300.000000   1300.000000   1300.000000
# 50%     1650.000000   1650.000000   1650.000000   1650.000000   1645.000000
# 75%     2150.000000   2150.000000   2141.250000   2100.000000   2100.000000
# max    43333.000000  40000.000000  43333.000000  37500.000000  39250.000000
#
# [8 rows x 121 columns]

# %%
MedianRentalPrice_Dataframe['State'].value_counts()
# Out:
# CA    253
# FL    227
# TX    140
# GA     82
# IL     73
# NJ     72
# MD     54
# VA     54
# MI     52
# NC     44
# CT     43
# WA     43
# CO     36
# PA     36
# AZ     32
# MO     31
# SC     28
# OH     27
# NY     25
# TN     25
# IN     25
# AL     23
# LA     23
# UT     22
# MA     22
# MN     21
# OK     19
# KS     16
# AR     16
# IA     15
# OR     13
# HI     13
# KY     10
# WI      9
# MS      9
# ID      8
# NM      8
# RI      8
# NV      7
# MT      6
# NE      4
# AK      4
# DE      4
# ND      3
# WV      3
# WY      3
# SD      3
# NH      3
# DC      1
# ME      1
# Name: State, dtype: int64

# %%
max(MedianRentalPrice_Dataframe['State'].value_counts())
# Out:
# 253

# %%
MedianRentalPrice_Dataframe['CountyName'].value_counts()
# Out:
# Los Angeles County    47
# Orange County         42
# Miami-Dade County     37
# Montgomery County     29
# Broward County        26
#                       ..
# Comanche County        1
# Sebastian County       1
# Laramie County         1
# Berks County           1
# Christian County       1
# Name: CountyName, Length: 492, dtype: int64

# %%
max(MedianRentalPrice_Dataframe['CountyName'].value_counts())
# Out:
# 47

# %%
MedianRentalPrice_Dataframe['RegionName'].value_counts()
# Out:
# Springfield        6
# Middletown         4
# Lakewood           4
# Lafayette          4
# Richmond           4
#                   ..
# Milpitas           1
# Rochester Hills    1
# Bethesda           1
# Winter Park        1
# Wainscott          1
# Name: RegionName, Length: 1549, dtype: int64

# %%
max(MedianRentalPrice_Dataframe['RegionName'].value_counts())
# Out:
# 6

# %%
MedianRentalPrice_Dataframe['2019-03'].value_counts()
# Out:
# 1500.0     55
# 1600.0     47
# 1250.0     44
# 1300.0     43
# 1800.0     37
#            ..
# 1545.0      1
# 2147.5      1
# 1837.5      1
# 1840.0      1
# 40000.0     1
# Name: 2019-03, Length: 417, dtype: int64

# %%
MedianRentalPrice_Dataframe['2015-03'].value_counts()
# Out:
# 1350.0    25
# 1250.0    24
# 1200.0    24
# 1300.0    23
# 1600.0    20
#           ..
# 985.0      1
# 1597.5     1
# 1439.0     1
# 1599.5     1
# 3100.0     1
# Name: 2015-03, Length: 229, dtype: int64

# %%
import matplotlib.pyplot as plt

MedianRentalPrice_Dataframe.hist(bins=50,figsize=(10,20))
plt.show()

# %%
corr_matrix = MedianRentalPrice_Dataframe.corr()

# %%
corr_matrix["2019-12"].sort_values(ascending=False)
# Out:
# 2019-12     1.000000
# 2019-11     0.997694
# 2019-10     0.996038
# 2019-09     0.995484
# 2019-08     0.993342
#               ...
# 2011-06     0.911972
# 2011-07     0.908988
# 2010-02     0.874229
# SizeRank    0.144152
# 2010-01          NaN
# Name: 2019-12, Length: 121, dtype: float64

# %% [markdown]
# ## Seperating Quantitative Data and Categorical Data.
# ---

# %%
quantative_columns = [f for f in MedianRentalPrice_Dataframe.columns if MedianRentalPrice_Dataframe.dtypes[f] != 'object']
categorical_colums = [f for f in MedianRentalPrice_Dataframe.columns if MedianRentalPrice_Dataframe.dtypes[f] == 'object']

# %%
quantative_columns
# Out:
# ['SizeRank',
#  '2010-01',
#  '2010-02',
#  '2010-03',
#  '2010-04',
#  '2010-05',
#  '2010-06',
#  '2010-07',
#  '2010-08',
#  '2010-09',
#  '2010-10',
#  '2010-11',
#  '2010-12',
#  '2011-01',
#  '2011-02',
#  '2011-03',
#  '2011-04',
#  '2011-05',
#  '2011-06',
#  '2011-07',
#  '2011-08',
#  '2011-09',
#  '2011-10',
#  '2011-11',
#  '2011-12',
#  '2012-01',
#  '2012-02',
#  '2012-03',
#  '2012-04',
#  '2012-05',
#  '2012-06',
#  '2012-07',
#  '2012-08',
#  '2012-09',
#  '2012-10',
#  '2012-11',
#  '2012-12',
#  '2013-01',
#  '2013-02',
#  '2013-03',
#  '2013-04',
#  '2013-05',
#  '2013-06',
#  '2013-07',
#  '2013-08',
#  '2013-09',
#  '2013-10',
#  '2013-11',
#  '2013-12',
#  '2014-01',
#  '2014-02',
#  '2014-03',
#  '2014-04',
#  '2014-05',
#  '2014-06',
#  '2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
#  '2015-07',
#  '2015-08',
#  '2015-09',
#  '2015-10',
#  '2015-11',
#  '2015-12',
#  '2016-01',
#  '2016-02',
#  '2016-03',
#  '2016-04',
#  '2016-05',
#  '2016-06',
#  '2016-07',
#  '2016-08',
#  '2016-09',
#  '2016-10',
#  '2016-11',
#  '2016-12',
#  '2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12',
#  '2018-01',
#  '2018-02',
#  '2018-03',
#  '2018-04',
#  '2018-05',
#  '2018-06',
#  '2018-07',
#  '2018-08',
#  '2018-09',
#  '2018-10',
#  '2018-11',
#  '2018-12',
#  '2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04',
#  '2019-05',
#  '2019-06',
#  '2019-07',
#  '2019-08',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2019-12']

# %%
quantatative_data = pd.DataFrame()
quantatative_dataframe.reset_index()
qualitative_dataframe = pd.Dataframe()
qualitative_dataframe.reset_index()

for column in quantative_columns:
    quantative_data= pd.concat((quantatative_data,MedianRentalPrice_Dataframe[column]),axis=1)

# %%
quantative_data
# Out:
#       2019-12
# 0      2900.0
# 1      3550.0
# 2      1500.0
# 3      1750.0
# 4      1300.0
# ...       ...
# 1694   3395.0
# 1695  35000.0
# 1696  31666.0
# 1697    909.0
# 1698  28333.0
#
# [1699 rows x 1 columns]
